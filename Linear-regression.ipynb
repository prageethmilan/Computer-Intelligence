# %%
import pandas as pd

# %%
salary = pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Salary%20Data.csv')

# %%
salary.columns
# Out:
# Index(['Experience Years', 'Salary'], dtype='object')

# %%
y = salary['Salary']

# %%
x = salary[['Experience Years']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y, train_size=0.7, random_state=2529)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((28, 1), (12, 1), (28,), (12,))

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# np.float64(26596.961311068262)

# %%
model.coef_
# Out:
# array([9405.61663234])

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([ 90555.15441095,  59516.61952424, 106544.70268592,  64219.42784041,
#         68922.23615658, 123474.81262412,  84911.78443155,  63278.86617718,
#         65159.98950364,  61397.74285071,  37883.70126987,  50111.00289191])

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# np.float64(4005.9263101681768)

# %%
mean_absolute_percentage_error(y_test, y_pred)
# Out:
# np.float64(0.06384602996141632)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# np.float64(24141421.671440993)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))

# %%
plt.scatter(X_test, y_test, color="blue", label="Actual Salary")
plt.scatter(X_test, y_pred, color="red", label="Predicted Salary")
plt.xlabel("Experience Years")
plt.ylabel("Salary")
plt.legend()
plt.title("Actual vs Predicted Salary")
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X_train, y_train, color="blue", label="Training Data")
plt.plot(X_train, model.predict(X_train), color="red", label="Regression Line")
plt.xlabel("Experience Years")
plt.ylabel("Salary")
plt.legend()
plt.title("Regression Line on Training Data")
plt.show()

# %%
m = model.coef_[0]
b = model.intercept_

# %%
equation_text = f"y = {m:.2f} * x + {b:.2f}"

# %%
print(equation_text)
# Out:
# y = 9405.62 * x + 26596.96

# %%
import seaborn as sns

# %%
sns.lmplot(x='Experience Years', y='Salary', data=salary, height=6, aspect=1.5, line_kws={'color': 'red'})
plt.title("Experience Years vs Salary with Regression Line")
plt.xlabel("Experience Years")
plt.ylabel("Salary")
plt.show()

# %%
train_data = pd.DataFrame({'Experience Years': X_train.values.flatten(), 'Salary': y_train.values})

# %%
sns.lmplot(x='Experience Years', y='Salary', data=train_data, height=6, aspect=1.5, line_kws={'color': 'red'})
plt.xlabel("Experience Years")
plt.ylabel("Salary")
plt.title("Regression Line on Training Data")
plt.show()
